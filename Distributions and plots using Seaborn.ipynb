# %%
#importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#reading the csv file using pandas 
df = pd.read_csv('train.csv')

# %%
#ploting a distplot with a list of numbers
sns.distplot([1,2,3,4,5], hist = False)
#showing the plot
plt.show()
# Out:
# C:\Users\husna\AppData\Local\Temp\ipykernel_4660\1996292606.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([1,2,3,4,5], hist = False)

# %%
#Normal Distribtuion and its plot
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)

#plotting the distplot of normal distibution
sns.distplot(x, hist=True)

plt.show()
# Out:
# [[ 0.24550798  1.38554381  0.38978043]
#  [-0.54569059  3.20071995 -0.85704572]]
# C:\Users\husna\AppData\Local\Temp\ipykernel_4660\3108287492.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist=True)

# %%
#Binominal distribution and its plot
sns.distplot(random.binomial(n= 10, p=0.7, size = 1000), hist = True, kde = True)
# Out:
# C:\Users\husna\AppData\Local\Temp\ipykernel_4660\194313282.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n= 10, p=0.7, size = 1000), hist = True, kde = True)
# <Axes: ylabel='Density'>

# %%
#Logistic Distribution and its plot
x = random.logistic(loc=0, scale= 2, size= 10)
sns.distplot([x])
# Out:
# C:\Users\husna\AppData\Local\Temp\ipykernel_4660\2782203283.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([x])
# <Axes: ylabel='Density'>

# %%
# Generating random samples from Chi-Square distribution
chi_square_samples = np.random.chisquare(5, 1000)

# Plotting the distribution
plt.figure(figsize=(8, 5))
sns.histplot(chi_square_samples, bins=30, kde=True, color='blue', stat='density')
plt.title('Chi-Square Distribution (df = 5)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid()
plt.show()
